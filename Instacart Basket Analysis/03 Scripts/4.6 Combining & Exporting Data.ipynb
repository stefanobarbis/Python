# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\stefa\OneDrive\Career Foundry\11.20 Instacart Basket Analysis'

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_clean.csv'), index_col = False)

# %%
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_prior.csv'), index_col = False)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           1   2398795        1    prior             2          3
# 1           2    473747        1    prior             3          3
# 2           3   2254736        1    prior             4          4
# 3           4    431534        1    prior             5          4
# 4           5   3367565        1    prior             6          2
#
#    order_hour_of_day  days_since_prior_order
# 0                  7                    15.0
# 1                 12                    21.0
# 2                  7                    29.0
# 3                 15                    28.0
# 4                  7                    19.0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3214874, 8)

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           1   2398795        1    prior             2          3
# 1           1   2398795        1    prior             2          3
# 2           1   2398795        1    prior             2          3
# 3           1   2398795        1    prior             2          3
# 4           1   2398795        1    prior             2          3
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  7                    15.0         196                  1
# 1                  7                    15.0       10258                  2
# 2                  7                    15.0       12427                  3
# 3                  7                    15.0       13176                  4
# 4                  7                    15.0       26088                  5
#
#    reordered _merge
# 0          1   both
# 1          0   both
# 2          1   both
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          30356421
# right_only           0
# left_only            0
# Name: _merge, dtype: int64

# %%
df_merged_large.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.csv'))

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# # Task 4.6

# %% [markdown]
# Question 3

# %%
df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders&products_combined.pkl'))

# %% [markdown]
# Question 4

# %%
df_orders_products_combined.shape
# Out:
# (30356421, 12)

# %% [markdown]
# Question 5

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           1   2398795        1    prior             2          3
# 1           1   2398795        1    prior             2          3
# 2           1   2398795        1    prior             2          3
# 3           1   2398795        1    prior             2          3
# 4           1   2398795        1    prior             2          3
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  7                    15.0         196                  1
# 1                  7                    15.0       10258                  2
# 2                  7                    15.0       12427                  3
# 3                  7                    15.0       13176                  4
# 4                  7                    15.0       26088                  5
#
#    reordered _merge
# 0          1   both
# 1          0   both
# 2          1   both
# ...

# %%
df_products = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_clean.csv'), index_col = False)

# %%
df_products.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_products.shape
# Out:
# (49672, 6)

# %%
df_merged = df_products.merge(df_orders_products_combined, on = 'product_id', how = 'inner')

# %%
df_merged
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 30328758         49692       49688      Fresh Foaming Cleanser        73
# 30328759         49692       49688      Fresh Foaming Cleanser        73
# 30328760         49692       49688      Fresh Foaming Cleanser        73
# 30328761         49692       49688      Fresh Foaming Cleanser        73
# 30328762         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  \
# ...

# %% [markdown]
# Question 6

# %%
df_merged['_merge'].value_counts()
# Out:
# both          30328763
# right_only           0
# left_only            0
# Name: _merge, dtype: int64

# %%
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
