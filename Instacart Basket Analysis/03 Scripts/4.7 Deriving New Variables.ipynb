# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\stefa\OneDrive\Career Foundry\11.20 Instacart Basket Analysis'

# %%
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders&products_merged.pkl'))

# %%
ords_prods_merged
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 30328758         49692       49688      Fresh Foaming Cleanser        73
# 30328759         49692       49688      Fresh Foaming Cleanser        73
# 30328760         49692       49688      Fresh Foaming Cleanser        73
# 30328761         49692       49688      Fresh Foaming Cleanser        73
# 30328762         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  \
# ...

# %%
df = ords_prods_merged[:1000000]

# %%
# Define a function

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply the function

df['price_range'] = df.apply(price_label, axis = 1)
# Out:
# <ipython-input-7-cb2ce0e33156>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis = 1)

# %%
df
# Out:
#         Unnamed: 0_x  product_id                     product_name  aisle_id  \
# 0                  0           1       Chocolate Sandwich Cookies        61
# 1                  0           1       Chocolate Sandwich Cookies        61
# 2                  0           1       Chocolate Sandwich Cookies        61
# 3                  0           1       Chocolate Sandwich Cookies        61
# 4                  0           1       Chocolate Sandwich Cookies        61
# ...              ...         ...                              ...       ...
# 999995          2164        2164  Waffles, Sweet Belgian, Vanilla        52
# 999996          2164        2164  Waffles, Sweet Belgian, Vanilla        52
# 999997          2164        2164  Waffles, Sweet Belgian, Vanilla        52
# 999998          2164        2164  Waffles, Sweet Belgian, Vanilla        52
# 999999          2164        2164  Waffles, Sweet Belgian, Vanilla        52
#
# ...

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    653498
# Low-range product    337952
# High range             8550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 24.5

# %%
ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-10bd3af0c37f> in <module>
# ----> 1 ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'
#
# NameError: name 'df_ords_prods_merged' is not defined

# %%
ords_prods_merged.loc[(ords_prods_merged['prices'] <= 15) & (ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    20462144
# Low-range product     9476774
# NaN                    389845
# Name: price_range_loc, dtype: int64

# %%
ords_prods_merged
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 30328758         49692       49688      Fresh Foaming Cleanser        73
# 30328759         49692       49688      Fresh Foaming Cleanser        73
# 30328760         49692       49688      Fresh Foaming Cleanser        73
# 30328761         49692       49688      Fresh Foaming Cleanser        73
# 30328762         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  \
# ...

# %%
for x in range(30,45):
    print("My age is %d" % (x))
# Out:
# My age is 30
# My age is 31
# My age is 32
# My age is 33
# My age is 34
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44

# %%
ords_prods_merged['order_dow'].value_counts(dropna = False)
# Out:
# 0    5779087
# 1    5303718
# 6    4190948
# 5    3952326
# 2    3947564
# 3    3600589
# 4    3554531
# Name: order_dow, dtype: int64

# %%
result = []

for value in ords_prods_merged["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
# ...

# %%
ords_prods_merged['busiest_day'] = result

# %%
ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    20995145
# Busiest day        5779087
# Least busy         3554531
# Name: busiest_day, dtype: int64

# %%
ords_prods_merged
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 30328758         49692       49688      Fresh Foaming Cleanser        73
# 30328759         49692       49688      Fresh Foaming Cleanser        73
# 30328760         49692       49688      Fresh Foaming Cleanser        73
# 30328761         49692       49688      Fresh Foaming Cleanser        73
# 30328762         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  \
# ...

# %% [markdown]
# # Task 4.7

# %% [markdown]
# Question 1: Adding price_range and busiest_day

# %%
ords_prods_merged
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 30328758         49692       49688      Fresh Foaming Cleanser        73
# 30328759         49692       49688      Fresh Foaming Cleanser        73
# 30328760         49692       49688      Fresh Foaming Cleanser        73
# 30328761         49692       49688      Fresh Foaming Cleanser        73
# 30328762         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  \
# ...

# %% [markdown]
# Question 2: Replacing busiest_day for busiest_days and slowest_days

# %%
result = []

for value in ords_prods_merged["order_dow"]:
  if value == 0 or value == 1:
    result.append("x")
  else:
    result.append("")

# %%
ords_prods_merged['busiest_days'] = result

# %%
ords_prods_merged
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 30328758         49692       49688      Fresh Foaming Cleanser        73
# 30328759         49692       49688      Fresh Foaming Cleanser        73
# 30328760         49692       49688      Fresh Foaming Cleanser        73
# 30328761         49692       49688      Fresh Foaming Cleanser        73
# 30328762         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  \
# ...

# %%
result = []

for value in ords_prods_merged["order_dow"]:
  if value == 3 or value == 4:
    result.append("x")
  else:
    result.append("")

# %%
ords_prods_merged['slowest_days'] = result

# %%
ords_prods_merged
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 30328758         49692       49688      Fresh Foaming Cleanser        73
# 30328759         49692       49688      Fresh Foaming Cleanser        73
# 30328760         49692       49688      Fresh Foaming Cleanser        73
# 30328761         49692       49688      Fresh Foaming Cleanser        73
# 30328762         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  \
# ...

# %%
ords_prods_merged.drop(columns = ['busiest_day'])
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 30328758         49692       49688      Fresh Foaming Cleanser        73
# 30328759         49692       49688      Fresh Foaming Cleanser        73
# 30328760         49692       49688      Fresh Foaming Cleanser        73
# 30328761         49692       49688      Fresh Foaming Cleanser        73
# 30328762         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  \
# ...

# %% [markdown]
# Question 3

# %%
ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
#      19245958
# x    11082805
# Name: busiest_days, dtype: int64

# %%
ords_prods_merged['slowest_days'].value_counts(dropna = False)
# Out:
#      23173643
# x     7155120
# Name: slowest_days, dtype: int64

# %% [markdown]
# Observations: There are more busiest_days than slowest days. Thats a good sign for the business!

# %% [markdown]
# Question 4: Adding busiest_period_of_day column

# %%
ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2593725
# 11    2564597
# 14    2517238
# 15    2487586
# 13    2487500
# 12    2445841
# 16    2364969
# 9     2311334
# 17    1943858
# 8     1622394
# 18    1520954
# 19    1169224
# 20     910005
# 7      844665
# 21     746254
# 22     592432
# 23     375889
# 6      274801
# 0      203460
# 1      108110
# 5       82706
# 2       63961
# 4       49400
# 3       47860
# Name: order_hour_of_day, dtype: int64

# %%
result = []

for value in ords_prods_merged["order_hour_of_day"]:
  if value == 10 or value == 11 or value == 14 or value == 15 or value == 13 or value == 12 or value == 16 or value == 9:
    result.append("Most orders")
  elif value == 17 or value == 8 or value == 18 or value == 19 or value == 20 or value == 7 or value == 21 or value == 22:
    result.append("Average orders")
  else:
    result.append("Fewest orders")

# %%
ords_prods_merged['busiest_period_of_day'] = result

# %%
ords_prods_merged
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 30328758         49692       49688      Fresh Foaming Cleanser        73
# 30328759         49692       49688      Fresh Foaming Cleanser        73
# 30328760         49692       49688      Fresh Foaming Cleanser        73
# 30328761         49692       49688      Fresh Foaming Cleanser        73
# 30328762         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  \
# ...

# %% [markdown]
# Question 5: Column Frequency

# %%
ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       19772790
# Average orders     9349786
# Fewest orders      1206187
# Name: busiest_period_of_day, dtype: int64

# %%
ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'op_days.pkl'))
